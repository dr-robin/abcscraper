# %%
#https://thesession.org/tunes/19413

from bs4 import BeautifulSoup
path = "/home/becode/dr-robin/abcscrape/session1.html"

with open (path, "rb") as htmlfile:
    data = htmlfile.read()

soup = BeautifulSoup(data, "html")

links = []
#https://thesession.org/tunes/500/abc/1
for link in soup.find_all('a'):
    links.append(link.get('href'))

abclinks = [k for k in links if '/abc/' in k]
downloadlinks = [k for k in links if '#download' in k]
morelinks = [m+str(n) for m,n in zip(linklist,downloadlinks)]
finallinks = ["https://thesession.org" + l for l in downloadlinks]
print(finallinks)





with open('your_file.txt', 'a') as file:
    file.writelines( "%s\n" % item for item in finallinks )
# Out:
# []

# %%
start = 0
end = 19413
num = list(range(start, end))
finallinks = ["https://thesession.org/tunes/" + str(l) + "/abc" for l in num]
#https://thesession.org/tunes/500/abc
len(finallinks)
# Out:
# 19413

# %%
finalfilenames = ["thesession.org/tunes/" + str(l) + "/abc" for l in num]
finalfilenames = [l.replace("/","-") for l in finalfilenames]

# %%
len(finalfilenames)
# Out:
# 19413

# %%
url = 'https://thesession.org/tunes/9/abc'
s = url[8:]

# %%
url
# Out:
# ['https://thesession.org/tunes/1/abc', 'https://thesession.org/tunes/2/abc']

# %%
###this works

from time import sleep
import os
import requests
import random

url = finallinks
path = "/home/becode/dr-robin/abcscrape/"

for i in url:
    try:
        r = requests.get(i)
        print(i, r.status_code)
        filename = i[8:].replace("/","-")
        f = open(os.path.join(path, filename),'wb+')
        f.write(r.content)
        sleep(random.randint(0.5, 5))
    except:
        continue
# Out:
# https://thesession.org/tunes/0/abc 200
# https://thesession.org/tunes/1/abc 200
# https://thesession.org/tunes/2/abc 200
# https://thesession.org/tunes/3/abc 200
# https://thesession.org/tunes/4/abc 200
# https://thesession.org/tunes/5/abc 200
# https://thesession.org/tunes/6/abc 200
# https://thesession.org/tunes/7/abc 200
# https://thesession.org/tunes/8/abc 200
# https://thesession.org/tunes/9/abc 200
# https://thesession.org/tunes/10/abc 200
# https://thesession.org/tunes/11/abc 200
# https://thesession.org/tunes/12/abc 200
# https://thesession.org/tunes/13/abc 200
# https://thesession.org/tunes/14/abc 200
# https://thesession.org/tunes/15/abc 200
# https://thesession.org/tunes/16/abc 200
# https://thesession.org/tunes/17/abc 200
# https://thesession.org/tunes/18/abc 200
# https://thesession.org/tunes/19/abc 200
# https://thesession.org/tunes/20/abc 200
# https://thesession.org/tunes/21/abc 200
# https://thesession.org/tunes/22/abc 200
# https://thesession.org/tunes/23/abc 200
# ...

# %%
filename.replace("/","-")
# Out:
# 'thesession.org-tunes-1-abc'

# %%
pwd
# Out:
# '/home/becode/dr-robin/abcscrape'

# %%
print(finallinks[1])
if url.find('/'):
    print(url.rsplit('/', 1)[1]
# Out:
#   File "<ipython-input-115-7f752bec67ec>", line 3
#     print(url.rsplit('/', 1)[1]
#                                ^
# SyntaxError: unexpected EOF while parsing

# %%
url = finallinks[1]
import requests

#url="https://thesession.org/tunes/500"
r = requests.get(url)
print(url, r.status_code)
open('1/abc', 'wb').write(r.content)
#soup = BeautifulSoup(r.content, "html")
#find div class "notes"

#path = "/home/becode/dr-robin/abcscrape/session1.html"

#with open (path, "rb") as htmlfile:
 #   data = htmlfile.read()

#soup = BeautifulSoup(data, "html")

#notes = soup.find(id="notes"##

soup.find_all(id=True)

soup.find_all("a")
#print(soup.a.prettify()

#id = abc1
#soup.find_all(name="div", id=True)
#soup.find_all(text="abc")
#div class = "notes"

links = []
#https://thesession.org/tunes/500/abc/1
for link in soup.find_all('a'):
    links.append(link.get('href'))

abclinks = [k for k in links if '/abc/' in k]
print(abclinks)

["https://thesession.org" + l for l in abclinks]
# Out:
# https://thesession.org/tunes/1/abc 200
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-113-ba9ca84ed5cc> in <module>
#       5 r = requests.get(url)
#       6 print(url, r.status_code)
# ----> 7 open('1/abc', 'wb').write(r.content)
#       8 #soup = BeautifulSoup(r.content, "html")
#       9 #find div class "notes"
#
# FileNotFoundError: [Errno 2] No such file or directory: '1/abc'

# %%
import requests
url="https://thesession.org/tunes/500/abc/1"
response = requests.get(url)

# %%
downloadlinks = [k for k in links if '#download' in k]
#print(downloadlinks)
abclinks = [k for k in links if '/abc/' in k]
#print(abclinks)
len(downloadlinks)
downloadlinks = [m+str(n) for m,n in zip(linklist,downloadlinks)]
linklist = ["https://thesession.org" + l for l in downloadlinks]
print(linklist)


[m+str(n) for m,n in zip(linklist,downloadlinks)]
# Out:
# ['https://thesession.orghttps://thesession.org/tunes/500/abc/1#download500#download500', 'https://thesession.orghttps://thesession.org/tunes/500/abc/2#download13413#download13413', 'https://thesession.orghttps://thesession.org/tunes/500/abc/3#download13414#download13414', 'https://thesession.orghttps://thesession.org/tunes/500/abc/4#download13415#download13415', 'https://thesession.orghttps://thesession.org/tunes/500/abc/5#download13416#download13416', 'https://thesession.orghttps://thesession.org/tunes/500/abc/6#download21580#download21580', 'https://thesession.orghttps://thesession.org/tunes/500/abc/7#download24976#download24976', 'https://thesession.orghttps://thesession.org/tunes/500/abc/8#download27960#download27960', 'https://thesession.orghttps://thesession.org/tunes/500/abc/9#download30069#download30069', 'https://thesession.orghttps://thesession.org/tunes/500/abc/10#download32805#download32805', 'https://thesession.orghttps://thesession.org/tunes/500/abc/11#download34089#dow
# ...

# %%
print(type(r.content))
# Out:
# <class 'bytes'>

# %%
with open (path, "rb") as htmlfile:
    data = htmlfile.read()

# %%
<!DOCTYPE html>
